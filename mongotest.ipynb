# %%
# import
from pymongo import MongoClient
from bson.objectid import ObjectId #這東西再透過ObjectID去尋找的時候會用到

# connection
conn = MongoClient("mongodb://cinema:cinema@140.121.196.23:4118") # 如果你只想連本機端的server你可以忽略，遠端的url填入: mongodb://<user_name>:<user_password>@ds<xxxxxx>.mlab.com:<xxxxx>/<database_name>，請務必既的把腳括號的內容代換成自己的資料。
db = conn.Grocery
items = db.grocery
for item in items.find():
    print(item)
#這是創建新資料的語法
#db.item.insert({"name":"test","phone":"1234567890"})
# Out:
# {'_id': ObjectId('5c35dc90212d8d0678e94538'), 'name': '熱銷 逼真 道具酒瓶  砸頭酒瓶 糖酒瓶 電影道具 惡作劇 整蠱 整人 嚇人 玩具 優木森【F0209】', 'img_url': 'http://140.121.196.23:4119/grocery_files21649687514845_416_m.jpg', 'price': '599'}
# {'_id': ObjectId('5c35dc90212d8d0678e94539'), 'name': 'pop子和pipi美的日常周邊 動漫T恤短袖 2色 二次元表情卡通惡搞衣服', 'img_url': 'http://140.121.196.23:4119/grocery_files21852347358323_428_m.jpg', 'price': '399'}
# {'_id': ObjectId('5c35dc90212d8d0678e9453a'), 'name': '3組免運 逼真 道具酒瓶 砸頭酒瓶 糖酒瓶 電影道具 影視製作 惡作劇 整蠱 整人 嚇人 解壓 玩具 禮物【F0209】', 'img_url': 'http://140.121.196.23:4119/grocery_files21824207759096_473_m.jpg', 'price': '599'}
# {'_id': ObjectId('5c35dc90212d8d0678e9453b'), 'name': '高音質低重音 Moecen聲式耳機-有線版超萌可愛耳機媲美魔音貓神耳機貓耳耳機 賣萌好聽直播必備  交換禮物  尾牙', 'img_url': 'http://140.121.196.23:4119/grocery_files21715839545549_415_m.jpg', 'price': '1,680'}
# ...
